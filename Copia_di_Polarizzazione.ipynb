# %% [markdown]
# <a href="https://colab.research.google.com/github/salv0304/Colab/blob/main/Copia_di_Polarizzazione.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Relazione Polarizzazione**

# %%
import numpy as np
from scipy import optimize as sop
from scipy import constants as scc
import matplotlib.pyplot as plt  
from google.colab import files
import pandas as pd
from google.colab import files
from scipy.optimize import curve_fit

# %% [markdown]
# ##Esperimento 1, La Legge di Malus

# %% [markdown]
# Usando due polarizzatori lineari ruotati di un angolo $θ$, verifichiamo la **Legge di
# Malus**:
#
# $I(\theta)=I_0cos^2(\theta)$.

# %%
plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
dati=np.loadtxt("exp1.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
dati = dati.astype(np.float)
i=dati[:,1] #Intensità (mV)
I= [i/1000 for i in i]
angolo=dati[:,0] #radianti


print("\I (V) \t\tAngolo (deg)")
for i in range(len(I)):
  print(I[i],"\t",angolo[i])


plt.scatter(angolo, I, color='red')

plt.title("Dati Sperimentali")
plt.grid(True)
plt.xlabel("Angolo (deg)")
plt.ylabel("Intensità (V)")
plt.legend()
# Out:
# <ipython-input-3-7e4f185d1b91>:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati=np.loadtxt("exp1.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
# <ipython-input-3-7e4f185d1b91>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati = dati.astype(np.float)
# ...

# %%
def funzione(theta):
    intens= 0.342*(np.cos(np.radians(theta)))**2
    return intens

# %%
                                                                                                
  #plotting fit result
  ndata=len(angolo)
  plt.figure(figsize=[10,6])
  xmin,xmax=angolo[0],angolo[ndata-1]
  x=np.arange(xmin,xmax+1e-5,0.01)
  y=funzione(x)
  plt.xlabel('Angolo (deg)', fontsize=20)
  plt.ylabel('Intensità (V)', fontsize=20)
  plt.xticks(fontsize=10)
  plt.yticks(fontsize=10)
  plt.plot(angolo, I, 'o',markersize=8,label="Exp.")
  plt.plot(x,y,label="Funzione Teorica")
  plt.grid(True)
  plt.legend()
  plt.show()

# %% [markdown]
# ##Esperimento 2, Lamina $\lambda /2$

# %% [markdown]
# Usando un polarizzatore lineare seguito da una lamina $𝜆/2$, analizziamo la
# luce uscente con un secondo polarizzatore e mostriamo che la luce uscente è
# polarizzata linearmente, con direzione di polarizzazione che si ottiene
# tramite la riflessione speculare della polarizzazione incidente, rispetto a
# uno degli assi ottici della lamina.
#
#
#
# Abbiamo ottenuto i valori riportati nella seguente tabella
#
#
#
# \begin{array}{|&|}
# \hline
# \hline
# &Massimo &  & & Minimo\\
# \hline
# \theta_1 (deg) & I_{max}(mV) & \theta_2 (deg) & & I_{min}(mV) & \theta_2\\
# \hline
#  30&296 & 60 & & 6 & 150  \\
# \hline
#  60&292 &120 & & 6 & 30 \\
# \hline
#  90& 300 &0 & &3 & 90 \\
# \hline
#  120& 296 & 60 & & 6,4 & 150 \\
#  \hline
#  150& 290 & 120 & & 5.8 & 30\\
#  \hline
#  180& 300 & 0 & & 3.2 & 90\\
# \hline
# \end{array}

# %% [markdown]
# ##Esperimento 3, Lamina $\lambda/4$

# %% [markdown]
# ###Punto a
#
# Abbiamo veificato in laboratorio che, usando solo un polarizzatore e la lamina $𝜆/4$, la lamina non
# modifica l’intensità del fascio in quanto la luce viene polarizzata in generale
# ellitticamente (con polarizzazione lineare o circolare come casi particolari) ma
# con la stessa intensità.

# %% [markdown]
# ###Punto b
#
# Quando la lamina è orientata ad un angolo $𝜃1 = 0°$ o $𝜃1 = 90°$ rispetto al primo
# polarizzatore, la luce uscente è polarizzata linearmente, per cui mettendo un secondo
# polarizzatore lineare ad un angolo $𝜃_2$ l’intensità uscente varia come $cos^2(𝜃_2)$.
#
# \begin{array}{|&|}
# \hline
# \hline
# & \Theta_1=0° & & &\Theta_1=90° \\
# \hline
# \theta_2 (deg) & I (mV) & I/I_0  & &  I (mV) & I/I_0\\
# \hline
#  0&304 & 1 & &  306 &  1  \\
# \hline
#  90&4.2 &0.014 & & 3.8 & 0.012 \\
# \hline
#  45& 158 &0.151 & &150 & 0.490 \\
# \hline
# \end{array}

# %% [markdown]
# ###Punto c
#
# Quando la lamina è orientata ad un angolo $𝜃_1 = 45°$ o $135°$ rispetto al primo
# polarizzatore, la luce uscente è polarizzata circolarmente, per cui mettendo un secondo
# polarizzatore lineare l’intensità uscente non dipende dalla direzione di quest’ultimo.

# %%
plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
dati=np.loadtxt("exp3.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
dati = dati.astype(np.float)
I_I0=dati[:,2]
angolo=dati[:,0] #deg
Angolo= [np.radians(i) for i in angolo]


print("\I/I0 \t\tAngolo (deg)")
for i in range(len(I)):
  print(I_I0[i],"\t",angolo[i])
plt.polar(Angolo,I_I0, '-') 
plt.show()

plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
plt.scatter(angolo, I_I0, color='red')
plt.title("Dati Sperimentali")
plt.ylim(0,1.2)
plt.grid(True)
plt.xlabel("Angolo (deg)")
plt.ylabel("I/I0")
plt.legend()
  
  
# display the Polar plot
plt.show()
# Out:
# <ipython-input-57-a2f8d014945a>:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati=np.loadtxt("exp3.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
# <ipython-input-57-a2f8d014945a>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati = dati.astype(np.float)
# \I/I0 		Angolo (deg)
# 1.0 	 0.0
# ...

# %% [markdown]
# ###Punto d
#
# Quando la lamina è orientata ad un angolo $𝜃_1$ diverso da $0°, 45°, 90°, 135°$ rispetto al
# primo polarizzatore, la luce uscente è polarizzata ellitticamente, per cui mettendo un
# secondo polarizzatore lineare l’intensità uscente avrà la forma $f(\theta_2)=I_xcos^2(\theta_2-\theta_0)+I_ysin^2(\theta_2-\theta_0)$.

# %% [markdown]
# #### $\theta_2=30°$
#
#
# Mettiamo il secondo polarizzatore lineare a $\theta_2=30°$ e vediamo cosa succede

# %%
plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
dati=np.loadtxt("exp3_30.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
dati = dati.astype(np.float)
i=dati[:,1] #Intensità (mV)
I= [i/1000 for i in i]
angolo=dati[:,0] #radianti
Angolo= [np.radians(i) for i in angolo]

print("I (V) \t\tAngolo (deg)")
for i in range(len(I)):
  print(I[i],"\t",angolo[i])

plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
plt.scatter(angolo, I, color='blue')
plt.ylim(0,0.32)
plt.title("Dati Sperimentali")
plt.grid(True)
plt.xlabel("Angolo (deg)")
plt.ylabel("Intensità (V)")
plt.legend()
plt.show()


plt.figure(figsize=[8,6])
plt.polar(Angolo,I, '-') 
plt.show()
# Out:
# <ipython-input-13-01044b7a1077>:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati=np.loadtxt("exp3_30.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
# <ipython-input-13-01044b7a1077>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati = dati.astype(np.float)
# ...

# %%
def funzione(theta,I_x,I_y,theta_0):
    intens=I_x*(np.cos(np.radians(theta-theta_0)))**2 + I_y*(np.sin(np.radians(theta-theta_0)))**2
    return intens

# %%
# Fitting routine
# esegue il fit dei dati a partire da una stima dei dati iniziali
#
 
def fitplot(I_x, I_y, theta_0, print_output=True, plot_guess=False):
 
  guess = np.array([I_x, I_y, theta_0]) #array of initial guesses
  bounds = ([-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]) 
 
  global popt, pcov    #declare fit results as global variables
 
  plt.figure(figsize=(9, 6))
 
  popt, pcov = curve_fit(funzione, angolo, I, p0=guess, bounds=bounds)

  if plot_guess:
    plt.plot(t, funzione(t, guess[0], guess[1], guess[2]),'--', color=[0.3,0.7,0], label="Guess", linewidth=20) # plot guess

                                                                                                
  #plotting fit result
  ndata=len(angolo)
  plt.figure(figsize=[10,6])
  xmin,xmax=angolo[0],angolo[ndata-1]
  x=np.arange(xmin,xmax+1e-5,0.01)
  y=funzione(x,popt[0], popt[1], popt[2])
  plt.xlabel('Angolo (rad)', fontsize=20)
  plt.ylabel('Intensità (V)', fontsize=20)
  plt.xticks(fontsize=10)
  plt.yticks(fontsize=10)
  plt.plot(angolo, I, 'o',markersize=8,label="Exp.")
  plt.plot(x,y,label="Fit")
  plt.grid(True)
  plt.legend()
  plt.show()
  
  if print_output:
    label = ["I_x", "I_y", "theta_0"]
    for l, v, e in zip(label, popt, np.sqrt(np.diag(pcov))) :
      print("%11s = %10.10f +- %7.10f" % (l ,v, e))
    print("\n")

# %%
#fitplot(A, B, print_output=True, plot_guess=False):
fitplot(0.2, 0.1, 0)
# Out:
#         I_x = 0.2177008807 +- 0.0004979034
#         I_y = 0.0879657860 +- 0.0004979034
#     theta_0 = 28.4397969731 +- 0.1795414165

# %% [markdown]
# #### $\theta_2=80°$
#
# Mettiamo il secondo polarizzatore lineare a $\theta_2=80°$ e vediamo cosa succede

# %%
plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
dati=np.loadtxt("exp3_80.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
dati = dati.astype(np.float)
i=dati[:,1] #Intensità (mV)
I= [i/1000 for i in i]
angolo=dati[:,0] #radianti
Angolo= [np.radians(i) for i in angolo]

print("I (V) \t\tAngolo (deg)")
for i in range(len(I)):
  print(I[i],"\t",angolo[i])


plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
plt.scatter(angolo, I, color='blue')
plt.ylim(0,0.32)
plt.title("Dati Sperimentali")
plt.grid(True)
plt.xlabel("Angolo (deg)")
plt.ylabel("Intensità (V)")
plt.legend()
plt.show()

plt.figure(figsize=[8,6])
plt.polar(Angolo,I, '-') 
plt.show()
# Out:
# <ipython-input-14-3ddaf4fdaa41>:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati=np.loadtxt("exp3_80.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
# <ipython-input-14-3ddaf4fdaa41>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati = dati.astype(np.float)
# ...

# %%
# Fitting routine
# esegue il fit dei dati a partire da una stima dei dati iniziali
#
 
def fitplot(I_x, I_y, theta_0, print_output=True, plot_guess=False):
 
  guess = np.array([I_x, I_y, theta_0]) #array of initial guesses
  bounds = ([-np.inf, -np.inf, -np.inf], [np.inf, np.inf, np.inf]) 
 
  global popt, pcov    #declare fit results as global variables
 
  plt.figure(figsize=(9, 6))
 
  popt, pcov = curve_fit(funzione, angolo, I, p0=guess, bounds=bounds)

  if plot_guess:
    plt.plot(t, funzione(t, guess[0], guess[1], guess[2]),'--', color=[0.3,0.7,0], label="Guess", linewidth=20) # plot guess

                                                                                                
  #plotting fit result
  ndata=len(angolo)
  plt.figure(figsize=[10,6])
  xmin,xmax=angolo[0],angolo[ndata-1]
  x=np.arange(xmin,xmax+1e-5,0.01)
  y=funzione(x,popt[0], popt[1], popt[2])
  plt.xlabel('Angolo (rad)', fontsize=20)
  plt.ylabel('Intensità (V)', fontsize=20)
  plt.xticks(fontsize=10)
  plt.yticks(fontsize=10)
  plt.plot(angolo, I, 'o',markersize=8,label="Exp.")
  plt.plot(x,y,label="Fit")
  plt.grid(True)
  plt.legend()
  plt.show()
  
  if print_output:
    label = ["I_x", "I_y", "theta_0"]
    for l, v, e in zip(label, popt, np.sqrt(np.diag(pcov))) :
      print("%11s = %10.10f +- %7.10f" % (l ,v, e))
    print("\n")

# %%
#fitplot(A, B, print_output=True, plot_guess=False):
fitplot(0.3, 0.01, 0)
# Out:
#         I_x = 0.2975756834 +- 0.0010793164
#         I_y = 0.0109798722 +- 0.0010793165
#     theta_0 = -9.4097245340 +- 0.1761797750

# %% [markdown]
# ##Esperimento 4

# %% [markdown]
# ###Punto a
#
# Dimostriamo la non polarizzazione della luce del led.
#
# $I_0=0.96 mV$ è l'intensità del Led, utilizzando un polarizzatore lineare verifichiamo che la luce uscente non dipende dalla direzione di polarizzazione e ha un'intensità  $I=\frac{I_0}{2}$. Quindi al variare di $\theta$ dovremmo ottenere un valore costante.

# %%
plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
dati=np.loadtxt("exp4_a.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
dati = dati.astype(np.float)
i=dati[:,1] #Intensità (mV)
I= [i/1000 for i in i]
angolo=dati[:,0] #radianti


print("\I (V) \t\tAngolo (deg)")
for i in range(len(I)):
  print(I[i],"\t",angolo[i])


plt.scatter(angolo, I, color='red')
plt.ylim(0,0.7)
plt.title("Dati Sperimentali")
plt.grid(True)
plt.xlabel("Angolo (deg)")
plt.ylabel("Intensità (V)")
plt.legend()
# Out:
# <ipython-input-7-261168dd0e30>:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati=np.loadtxt("exp4_nonpol.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
# <ipython-input-7-261168dd0e30>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati = dati.astype(np.float)
# ...

# %% [markdown]
# ###Punto b
#
# Ci chiediamo se la luce del led è non polarizzata o circolarmente polarizzata.
#
# A seguito del punto a), la luce del LED può essere non polarizzata, oppure
# polarizzata circolarmente. Per distinguere le due situazioni, usare come
# “analizzatore circolare” una lamina $λ/4$ seguita da un polarizzatore lineare a $45°$ gradi
# rispetto agli assi della lamina. Nel caso di luce non polarizzata ancora al variare di $\theta$ dovremmo ottenere un valore costante.

# %%
plt.figure(figsize=[8,6])
plotSizeX=40                                     # Dimensione in X del grafico
plotSizeY= 400
dati=np.loadtxt("exp4_b.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
dati = dati.astype(np.float)
i=dati[:,1] #Intensità (mV)
I= [i/1000 for i in i]
angolo=dati[:,0] #radianti


print("\I (V) \t\tAngolo (deg)")
for i in range(len(I)):
  print(I[i],"\t",angolo[i])


plt.scatter(angolo, I, color='red')
plt.ylim(0,0.7)
plt.title("Dati Sperimentali")
plt.grid(True)
plt.xlabel("Angolo (deg)")
plt.ylabel("Intensità (V)")
plt.legend()
# Out:
# <ipython-input-12-a3351008e450>:4: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati=np.loadtxt("exp4_b.txt", dtype=np.str, delimiter="\t", skiprows=1) #scarto l'header del file
# <ipython-input-12-a3351008e450>:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dati = dati.astype(np.float)
# ...

# %% [markdown]
# Così concludiamo che la luce del LED è effettivamente non polarizzata.
